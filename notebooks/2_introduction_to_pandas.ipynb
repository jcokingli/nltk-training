# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sassoftware/sas-viya-programming/master/data/cars.csv')
print(df)

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP           float64
# Invoice        float64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
# Make           428 non-null object
# Model          428 non-null object
# Type           428 non-null object
# Origin         428 non-null object
# DriveTrain     428 non-null object
# MSRP           428 non-null float64
# Invoice        428 non-null float64
# EngineSize     428 non-null float64
# Cylinders      426 non-null float64
# Horsepower     428 non-null float64
# MPG_City       428 non-null float64
# MPG_Highway    428 non-null float64
# Weight         428 non-null float64
# Wheelbase      428 non-null float64
# Length         428 non-null float64
# dtypes: float64(10), object(5)
# memory usage: 50.2+ KB

# %%
subdf = df[['Make', 'Model', 'Horsepower']]
subdf

# %%
model = df.Model
model.head()
# Out:
# 0               MDX
# 1    RSX Type S 2dr
# 2           TSX 4dr
# 3            TL 4dr
# 4        3.5 RL 4dr
# Name: Model, dtype: object

# %%
df.iloc[3:7]
# Out:
#     Make                    Model    Type Origin DriveTrain     MSRP  Invoice  \
# 3  Acura                   TL 4dr   Sedan   Asia      Front  33195.0  30299.0
# 4  Acura               3.5 RL 4dr   Sedan   Asia      Front  43755.0  39014.0
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  46100.0  41100.0
# 6  Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  89765.0  79978.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
# 5         3.5        6.0       225.0      18.0         24.0  3893.0
# 6         3.2        6.0       290.0      17.0         24.0  3153.0
#
#    Wheelbase  Length
# 3      108.0   186.0
# 4      115.0   197.0
# 5      115.0   197.0
# 6      100.0   174.0

# %%
df.loc[3:7]
# Out:
#     Make                    Model    Type  Origin DriveTrain     MSRP  \
# 3  Acura                   TL 4dr   Sedan    Asia      Front  33195.0
# 4  Acura               3.5 RL 4dr   Sedan    Asia      Front  43755.0
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  46100.0
# 6  Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  89765.0
# 7   Audi              A4 1.8T 4dr   Sedan  Europe      Front  25940.0
#
#    Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 3  30299.0         3.2        6.0       270.0      20.0         28.0  3575.0
# 4  39014.0         3.5        6.0       225.0      18.0         24.0  3880.0
# 5  41100.0         3.5        6.0       225.0      18.0         24.0  3893.0
# 6  79978.0         3.2        6.0       290.0      17.0         24.0  3153.0
# 7  23508.0         1.8        4.0       170.0      22.0         31.0  3252.0
#
#    Wheelbase  Length
# 3      108.0   186.0
# 4      115.0   197.0
# 5      115.0   197.0
# 6      100.0   174.0
# 7      104.0   179.0

# %%
df.loc[[3, 10]]
# Out:
#      Make                      Model   Type  Origin DriveTrain     MSRP  \
# 3   Acura                     TL 4dr  Sedan    Asia      Front  33195.0
# 10   Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  33430.0
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 3   30299.0         3.2        6.0       270.0      20.0         28.0  3575.0
# 10  30366.0         3.0        6.0       220.0      17.0         26.0  3583.0
#
#     Wheelbase  Length
# 3       108.0   186.0
# 10      104.0   179.0

# %%
df = df.set_index('Model')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Model'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-4531be14e9b4> in <module>()
# ----> 1 df = df.set_index('Model')
#       2 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3144                 names.append(None)
#    3145             else:
# -> 3146                 level = frame[col]._values
#    3147                 names.append(col)
#    3148                 if drop:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Model'

# %%
df.loc['MDX']
# Out:
# Make           Acura
# Type             SUV
# Origin          Asia
# DriveTrain       All
# MSRP           36945
# Invoice        33337
# EngineSize       3.5
# Cylinders          6
# Horsepower       265
# MPG_City          17
# MPG_Highway       23
# Weight          4451
# Wheelbase        106
# Length           189
# Name: MDX, dtype: object

# %%
df.loc[['TSX 4dr', 'TL 4dr']]
# Out:
#           Make   Type Origin DriveTrain     MSRP  Invoice  EngineSize  \
# Model
# TSX 4dr  Acura  Sedan   Asia      Front  26990.0  24647.0         2.4
# TL 4dr   Acura  Sedan   Asia      Front  33195.0  30299.0         3.2
#
#          Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  \
# Model
# TSX 4dr        4.0       200.0      22.0         29.0  3230.0      105.0
# TL 4dr         6.0       270.0      20.0         28.0  3575.0      108.0
#
#          Length
# Model
# TSX 4dr   183.0
# TL 4dr    186.0

# %%
df['MSRP'] < 2000
#df.MSRP <2000
df[df['MSRP'] > 30000]
# Out:
#                                         Make    Type  Origin DriveTrain  \
# Model
# MDX                                    Acura     SUV    Asia        All
# TL 4dr                                 Acura   Sedan    Asia      Front
# 3.5 RL 4dr                             Acura   Sedan    Asia      Front
# 3.5 RL w/Navigation 4dr                Acura   Sedan    Asia      Front
# NSX coupe 2dr manual S                 Acura  Sports    Asia       Rear
# A41.8T convertible 2dr                  Audi   Sedan  Europe      Front
# A4 3.0 4dr                              Audi   Sedan  Europe      Front
# A4 3.0 Quattro 4dr manual               Audi   Sedan  Europe        All
# A4 3.0 Quattro 4dr auto                 Audi   Sedan  Europe        All
# A6 3.0 4dr                              Audi   Sedan  Europe      Front
# A6 3.0 Quattro 4dr                      Audi   Sedan  Europe        All
# A4 3.0 convertible 2dr                  Audi   Sedan  Europe      Front
# A4 3.0 Quattro convertible 2dr          Audi   Sedan  Europe        All
# A6 2.7 Turbo Quattro 4dr                Audi   Sedan  Europe        All
# A6 4.2 Quattro 4dr                      Audi   Sedan  Europe        All
# A8 L Quattro 4dr                        Audi   Sedan  Europe        All
# S4 Quattro 4dr                          Audi   Sedan  Europe        All
# RS 6 4dr                                Audi  Sports  Europe      Front
# TT 1.8 convertible 2dr (coupe)          Audi  Sports  Europe      Front
# TT 1.8 Quattro 2dr (convertible)        Audi  Sports  Europe        All
# TT 3.2 coupe 2dr (convertible)          Audi  Sports  Europe        All
# A6 3.0 Avant Quattro                    Audi   Wagon  Europe        All
# S4 Avant Quattro                        Audi   Wagon  Europe        All
# X3 3.0i                                  BMW     SUV  Europe        All
# X5 4.4i                                  BMW     SUV  Europe        All
# 325Ci 2dr                                BMW   Sedan  Europe       Rear
# 325Ci convertible 2dr                    BMW   Sedan  Europe       Rear
# 325xi 4dr                                BMW   Sedan  Europe        All
# 330i 4dr                                 BMW   Sedan  Europe       Rear
# 330Ci 2dr                                BMW   Sedan  Europe       Rear
# ...                                      ...     ...     ...        ...
# Boxster convertible 2dr              Porsche  Sports  Europe       Rear
# Boxster S convertible 2dr            Porsche  Sports  Europe       Rear
# 9-3 Arc Sport 4dr                       Saab   Sedan  Europe      Front
# 9-3 Aero 4dr                            Saab   Sedan  Europe      Front
# 9-5 Arc 4dr                             Saab   Sedan  Europe      Front
# 9-5 Aero 4dr                            Saab   Sedan  Europe      Front
# 9-3 Arc convertible 2dr                 Saab   Sedan  Europe      Front
# 9-3 Aero convertible 2dr                Saab   Sedan  Europe      Front
# 9-5 Aero                                Saab   Wagon  Europe      Front
# Outback H-6 VDC 4dr                   Subaru   Sedan    Asia        All
# Impreza WRX STi 4dr                   Subaru  Sports    Asia        All
# Sequoia SR5                           Toyota     SUV    Asia        All
# Land Cruiser                          Toyota     SUV    Asia        All
# Avalon XLS 4dr                        Toyota   Sedan    Asia      Front
# Touareg V6                        Volkswagen     SUV  Europe        All
# Passat GLX V6 4MOTION 4dr         Volkswagen   Sedan  Europe      Front
# Passat W8 4MOTION 4dr             Volkswagen   Sedan  Europe      Front
# Phaeton 4dr                       Volkswagen   Sedan  Europe      Front
# Phaeton W12 4dr                   Volkswagen   Sedan  Europe      Front
# Passat W8                         Volkswagen   Wagon  Europe      Front
# XC90 T6                                Volvo     SUV  Europe        All
# S60 2.5 4dr                            Volvo   Sedan  Europe        All
# S60 T5 4dr                             Volvo   Sedan  Europe      Front
# S60 R 4dr                              Volvo   Sedan  Europe        All
# S80 2.9 4dr                            Volvo   Sedan  Europe      Front
# S80 2.5T 4dr                           Volvo   Sedan  Europe        All
# C70 LPT convertible 2dr                Volvo   Sedan  Europe      Front
# C70 HPT convertible 2dr                Volvo   Sedan  Europe      Front
# S80 T6 4dr                             Volvo   Sedan  Europe      Front
# XC70                                   Volvo   Wagon  Europe        All
#
#                                      MSRP  Invoice  EngineSize  Cylinders  \
# Model
# MDX                               36945.0  33337.0         3.5        6.0
# TL 4dr                            33195.0  30299.0         3.2        6.0
# 3.5 RL 4dr                        43755.0  39014.0         3.5        6.0
# 3.5 RL w/Navigation 4dr           46100.0  41100.0         3.5        6.0
# NSX coupe 2dr manual S            89765.0  79978.0         3.2        6.0
# A41.8T convertible 2dr            35940.0  32506.0         1.8        4.0
# A4 3.0 4dr                        31840.0  28846.0         3.0        6.0
# A4 3.0 Quattro 4dr manual         33430.0  30366.0         3.0        6.0
# A4 3.0 Quattro 4dr auto           34480.0  31388.0         3.0        6.0
# A6 3.0 4dr                        36640.0  33129.0         3.0        6.0
# A6 3.0 Quattro 4dr                39640.0  35992.0         3.0        6.0
# A4 3.0 convertible 2dr            42490.0  38325.0         3.0        6.0
# A4 3.0 Quattro convertible 2dr    44240.0  40075.0         3.0        6.0
# A6 2.7 Turbo Quattro 4dr          42840.0  38840.0         2.7        6.0
# A6 4.2 Quattro 4dr                49690.0  44936.0         4.2        8.0
# A8 L Quattro 4dr                  69190.0  64740.0         4.2        8.0
# S4 Quattro 4dr                    48040.0  43556.0         4.2        8.0
# RS 6 4dr                          84600.0  76417.0         4.2        8.0
# TT 1.8 convertible 2dr (coupe)    35940.0  32512.0         1.8        4.0
# TT 1.8 Quattro 2dr (convertible)  37390.0  33891.0         1.8        4.0
# TT 3.2 coupe 2dr (convertible)    40590.0  36739.0         3.2        6.0
# A6 3.0 Avant Quattro              40840.0  37060.0         3.0        6.0
# S4 Avant Quattro                  49090.0  44446.0         4.2        8.0
# X3 3.0i                           37000.0  33873.0         3.0        6.0
# X5 4.4i                           52195.0  47720.0         4.4        8.0
# 325Ci 2dr                         30795.0  28245.0         2.5        6.0
# 325Ci convertible 2dr             37995.0  34800.0         2.5        6.0
# 325xi 4dr                         30245.0  27745.0         2.5        6.0
# 330i 4dr                          35495.0  32525.0         3.0        6.0
# 330Ci 2dr                         36995.0  33890.0         3.0        6.0
# ...                                   ...      ...         ...        ...
# Boxster convertible 2dr           43365.0  37886.0         2.7        6.0
# Boxster S convertible 2dr         52365.0  45766.0         3.2        6.0
# 9-3 Arc Sport 4dr                 30860.0  29269.0         2.0        4.0
# 9-3 Aero 4dr                      33360.0  31562.0         2.0        4.0
# 9-5 Arc 4dr                       35105.0  33011.0         2.3        4.0
# 9-5 Aero 4dr                      39465.0  37721.0         2.3        4.0
# 9-3 Arc convertible 2dr           40670.0  38520.0         2.0        4.0
# 9-3 Aero convertible 2dr          43175.0  40883.0         2.0        4.0
# 9-5 Aero                          40845.0  38376.0         2.3        4.0
# Outback H-6 VDC 4dr               31545.0  28603.0         3.0        6.0
# Impreza WRX STi 4dr               31545.0  29130.0         2.5        4.0
# Sequoia SR5                       35695.0  31827.0         4.7        8.0
# Land Cruiser                      54765.0  47986.0         4.7        8.0
# Avalon XLS 4dr                    30920.0  27271.0         3.0        6.0
# Touareg V6                        35515.0  32243.0         3.2        6.0
# Passat GLX V6 4MOTION 4dr         33180.0  30583.0         2.8        6.0
# Passat W8 4MOTION 4dr             39235.0  36052.0         4.0        8.0
# Phaeton 4dr                       65000.0  59912.0         4.2        8.0
# Phaeton W12 4dr                   75000.0  69130.0         6.0       12.0
# Passat W8                         40235.0  36956.0         4.0        8.0
# XC90 T6                           41250.0  38851.0         2.9        6.0
# S60 2.5 4dr                       31745.0  29916.0         2.5        5.0
# S60 T5 4dr                        34845.0  32902.0         2.3        5.0
# S60 R 4dr                         37560.0  35382.0         2.5        5.0
# S80 2.9 4dr                       37730.0  35542.0         2.9        6.0
# S80 2.5T 4dr                      37885.0  35688.0         2.5        5.0
# C70 LPT convertible 2dr           40565.0  38203.0         2.4        5.0
# C70 HPT convertible 2dr           42565.0  40083.0         2.3        5.0
# S80 T6 4dr                        45210.0  42573.0         2.9        6.0
# XC70                              35145.0  33112.0         2.5        5.0
#
#                                   Horsepower  MPG_City  MPG_Highway  Weight  \
# Model
# MDX                                    265.0      17.0         23.0  4451.0
# TL 4dr                                 270.0      20.0         28.0  3575.0
# 3.5 RL 4dr                             225.0      18.0         24.0  3880.0
# 3.5 RL w/Navigation 4dr                225.0      18.0         24.0  3893.0
# NSX coupe 2dr manual S                 290.0      17.0         24.0  3153.0
# A41.8T convertible 2dr                 170.0      23.0         30.0  3638.0
# A4 3.0 4dr                             220.0      20.0         28.0  3462.0
# A4 3.0 Quattro 4dr manual              220.0      17.0         26.0  3583.0
# A4 3.0 Quattro 4dr auto                220.0      18.0         25.0  3627.0
# A6 3.0 4dr                             220.0      20.0         27.0  3561.0
# A6 3.0 Quattro 4dr                     220.0      18.0         25.0  3880.0
# A4 3.0 convertible 2dr                 220.0      20.0         27.0  3814.0
# A4 3.0 Quattro convertible 2dr         220.0      18.0         25.0  4013.0
# A6 2.7 Turbo Quattro 4dr               250.0      18.0         25.0  3836.0
# A6 4.2 Quattro 4dr                     300.0      17.0         24.0  4024.0
# A8 L Quattro 4dr                       330.0      17.0         24.0  4399.0
# S4 Quattro 4dr                         340.0      14.0         20.0  3825.0
# RS 6 4dr                               450.0      15.0         22.0  4024.0
# TT 1.8 convertible 2dr (coupe)         180.0      20.0         28.0  3131.0
# TT 1.8 Quattro 2dr (convertible)       225.0      20.0         28.0  2921.0
# TT 3.2 coupe 2dr (convertible)         250.0      21.0         29.0  3351.0
# A6 3.0 Avant Quattro                   220.0      18.0         25.0  4035.0
# S4 Avant Quattro                       340.0      15.0         21.0  3936.0
# X3 3.0i                                225.0      16.0         23.0  4023.0
# X5 4.4i                                325.0      16.0         22.0  4824.0
# 325Ci 2dr                              184.0      20.0         29.0  3197.0
# 325Ci convertible 2dr                  184.0      19.0         27.0  3560.0
# 325xi 4dr                              184.0      19.0         27.0  3461.0
# 330i 4dr                               225.0      20.0         30.0  3285.0
# 330Ci 2dr                              225.0      20.0         30.0  3285.0
# ...                                      ...       ...          ...     ...
# Boxster convertible 2dr                228.0      20.0         29.0  2811.0
# Boxster S convertible 2dr              258.0      18.0         26.0  2911.0
# 9-3 Arc Sport 4dr                      210.0      20.0         28.0  3175.0
# 9-3 Aero 4dr                           210.0      20.0         28.0  3175.0
# 9-5 Arc 4dr                            220.0      21.0         29.0  3470.0
# 9-5 Aero 4dr                           250.0      21.0         29.0  3470.0
# 9-3 Arc convertible 2dr                210.0      21.0         29.0  3480.0
# 9-3 Aero convertible 2dr               210.0      21.0         30.0  3700.0
# 9-5 Aero                               250.0      19.0         29.0  3620.0
# Outback H-6 VDC 4dr                    212.0      19.0         26.0  3630.0
# Impreza WRX STi 4dr                    300.0      18.0         24.0  3263.0
# Sequoia SR5                            240.0      14.0         17.0  5270.0
# Land Cruiser                           325.0      13.0         17.0  5390.0
# Avalon XLS 4dr                         210.0      21.0         29.0  3439.0
# Touareg V6                             220.0      15.0         20.0  5086.0
# Passat GLX V6 4MOTION 4dr              190.0      19.0         26.0  3721.0
# Passat W8 4MOTION 4dr                  270.0      18.0         25.0  3953.0
# Phaeton 4dr                            335.0      16.0         22.0  5194.0
# Phaeton W12 4dr                        420.0      12.0         19.0  5399.0
# Passat W8                              270.0      18.0         25.0  4067.0
# XC90 T6                                268.0      15.0         20.0  4638.0
# S60 2.5 4dr                            208.0      20.0         27.0  3903.0
# S60 T5 4dr                             247.0      20.0         28.0  3766.0
# S60 R 4dr                              300.0      18.0         25.0  3571.0
# S80 2.9 4dr                            208.0      20.0         28.0  3576.0
# S80 2.5T 4dr                           194.0      20.0         27.0  3691.0
# C70 LPT convertible 2dr                197.0      21.0         28.0  3450.0
# C70 HPT convertible 2dr                242.0      20.0         26.0  3450.0
# S80 T6 4dr                             268.0      19.0         26.0  3653.0
# XC70                                   208.0      20.0         27.0  3823.0
#
#                                   Wheelbase  Length
# Model
# MDX                                   106.0   189.0
# TL 4dr                                108.0   186.0
# 3.5 RL 4dr                            115.0   197.0
# 3.5 RL w/Navigation 4dr               115.0   197.0
# NSX coupe 2dr manual S                100.0   174.0
# A41.8T convertible 2dr                105.0   180.0
# A4 3.0 4dr                            104.0   179.0
# A4 3.0 Quattro 4dr manual             104.0   179.0
# A4 3.0 Quattro 4dr auto               104.0   179.0
# A6 3.0 4dr                            109.0   192.0
# A6 3.0 Quattro 4dr                    109.0   192.0
# A4 3.0 convertible 2dr                105.0   180.0
# A4 3.0 Quattro convertible 2dr        105.0   180.0
# A6 2.7 Turbo Quattro 4dr              109.0   192.0
# A6 4.2 Quattro 4dr                    109.0   193.0
# A8 L Quattro 4dr                      121.0   204.0
# S4 Quattro 4dr                        104.0   179.0
# RS 6 4dr                              109.0   191.0
# TT 1.8 convertible 2dr (coupe)         95.0   159.0
# TT 1.8 Quattro 2dr (convertible)       96.0   159.0
# TT 3.2 coupe 2dr (convertible)         96.0   159.0
# A6 3.0 Avant Quattro                  109.0   192.0
# S4 Avant Quattro                      104.0   179.0
# X3 3.0i                               110.0   180.0
# X5 4.4i                               111.0   184.0
# 325Ci 2dr                             107.0   177.0
# 325Ci convertible 2dr                 107.0   177.0
# 325xi 4dr                             107.0   176.0
# 330i 4dr                              107.0   176.0
# 330Ci 2dr                             107.0   176.0
# ...                                     ...     ...
# Boxster convertible 2dr                95.0   170.0
# Boxster S convertible 2dr              95.0   170.0
# 9-3 Arc Sport 4dr                     105.0   183.0
# 9-3 Aero 4dr                          105.0   183.0
# 9-5 Arc 4dr                           106.0   190.0
# 9-5 Aero 4dr                          106.0   190.0
# 9-3 Arc convertible 2dr               105.0   182.0
# 9-3 Aero convertible 2dr              105.0   182.0
# 9-5 Aero                              106.0   190.0
# Outback H-6 VDC 4dr                   104.0   184.0
# Impreza WRX STi 4dr                   100.0   174.0
# Sequoia SR5                           118.0   204.0
# Land Cruiser                          112.0   193.0
# Avalon XLS 4dr                        107.0   192.0
# Touareg V6                            112.0   187.0
# Passat GLX V6 4MOTION 4dr             106.0   185.0
# Passat W8 4MOTION 4dr                 106.0   185.0
# Phaeton 4dr                           118.0   204.0
# Phaeton W12 4dr                       118.0   204.0
# Passat W8                             106.0   184.0
# XC90 T6                               113.0   189.0
# S60 2.5 4dr                           107.0   180.0
# S60 T5 4dr                            107.0   180.0
# S60 R 4dr                             107.0   181.0
# S80 2.9 4dr                           110.0   190.0
# S80 2.5T 4dr                          110.0   190.0
# C70 LPT convertible 2dr               105.0   186.0
# C70 HPT convertible 2dr               105.0   186.0
# S80 T6 4dr                            110.0   190.0
# XC70                                  109.0   186.0
#
# [190 rows x 14 columns]

# %%
df.plot(kind='scatter', x='MSRP', y='Horsepower', figsize=(12,6))

# %%
df.corr()
# Out:
#                  MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# MSRP         1.000000  0.999132    0.571753   0.649742    0.826945 -0.475020
# Invoice      0.999132  1.000000    0.564498   0.645226    0.823746 -0.470442
# EngineSize   0.571753  0.564498    1.000000   0.908002    0.787435 -0.709471
# Cylinders    0.649742  0.645226    0.908002   1.000000    0.810341 -0.684402
# Horsepower   0.826945  0.823746    0.787435   0.810341    1.000000 -0.676699
# MPG_City    -0.475020 -0.470442   -0.709471  -0.684402   -0.676699  1.000000
# MPG_Highway -0.439622 -0.434585   -0.717302  -0.676100   -0.647195  0.941021
# Weight       0.448426  0.442332    0.807867   0.742209    0.630796 -0.737966
# Wheelbase    0.152000  0.148328    0.636517   0.546730    0.387398 -0.507284
# Length       0.172037  0.166586    0.637448   0.547783    0.381554 -0.501526
#
#              MPG_Highway    Weight  Wheelbase    Length
# MSRP           -0.439622  0.448426   0.152000  0.172037
# Invoice        -0.434585  0.442332   0.148328  0.166586
# EngineSize     -0.717302  0.807867   0.636517  0.637448
# Cylinders      -0.676100  0.742209   0.546730  0.547783
# Horsepower     -0.647195  0.630796   0.387398  0.381554
# MPG_City        0.941021 -0.737966  -0.507284 -0.501526
# MPG_Highway     1.000000 -0.790989  -0.524661 -0.466092
# Weight         -0.790989  1.000000   0.760703  0.690021
# Wheelbase      -0.524661  0.760703   1.000000  0.889195
# Length         -0.466092  0.690021   0.889195  1.000000
